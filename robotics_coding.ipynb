# %% [markdown]
# <a href="https://colab.research.google.com/github/AnthonyChenEE/robotics_coding/blob/main/robotics_coding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Section 1：Python 编程题（40 分）**

# %% [markdown]
# 🧩 **Q1. 数组去重与排序（10 分）**
# 题目：
# 输入一个包含重复元素的整数数组，输出去重并升序排序后的结果。
# 📘 考点：集合去重、排序、基本语法。

# %%
def unique_sorted(nums):
    pass

# %%
def unique_sorted(nums):
  return sorted(list(set(nums)))

print(unique_sorted([5, 3, 1, 3, 2, 5]))
# Out:
# [1, 2, 3, 5]

# %% [markdown]
# 🧩 **Q2. 最大子数组和（Kadane算法）（15 分）**
# 题目：
# 给定整数数组 nums，返回连续子数组的最大和。
# 📘 考点：动态规划、O(n)算法。

# %%
def max_subarray(nums):
    pass

# %%
def max_subarray(nums):
  max_sum = curr = nums[0]
  for n in nums[1:]:
    curr = max(n, curr+n)
    max_sum = max(max_sum, curr)
  return max_sum

print(max_subarray([-2,1,-3,4,-1,2,1,-5,4]))
# Out:
# 6

# %% [markdown]
# **🧩 Q3. 字符串统计（15 分）**
# 题目：
# 统计字符串中每个字符出现的次数，按字母序输出。
#
# 📘 考点：字典操作、字符串遍历。

# %%
def char_count(s):
      pass

# %%
def char_count(s):
  count = {}
  for c in s:
    count[c] = count.get(c, 0) + 1
  return dict(sorted(count.items()))

print(char_count("Robotics"))
# Out:
# {'R': 1, 'b': 1, 'c': 1, 'i': 1, 'o': 2, 's': 1, 't': 1}

# %% [markdown]
# **Section 2：PyTorch 实现题（30 分）**

# %% [markdown]
# **⚙️ Q4. 实现一个简单的前馈神经网络（15 分）**
#
# 题目：
# 定义一个两层 MLP 模型（输入维度 10，隐藏层 32，输出维度 2），并写出前向传播函数。
#
# ✅ 参考答案：
# 📘 考点：nn.Module 基本结构、forward()、张量操作。

# %%
import torch
import torch.nn as nn

class MLP(nn.Module):
  def __init__(self):
    super().__init__()

    self.fc1 = nn.Linear(10, 32)
    self.relu = nn.ReLU()
    self.fc2 = nn.Linear(32, 2)

  def forward(self, x):
    x = self.fc1(x)
    x = self.relu(x)
    x = self.fc2(x)
    return x

model = MLP()
x = torch.randn(4, 10)
out = model(x)
print(out.shape)
# Out:
# torch.Size([4, 2])

# %% [markdown]
# **⚙️ Q5. 实现 Softmax 函数（15 分）**
#
# 题目：
# 实现一个数值稳定的 softmax 函数。
# 📘 考点：张量运算、数值稳定性。

# %%
import torch

def softmax(x):
  x = x - torch.max(x)
  exp_x = torch.exp(x)
  return exp_x / torch.sum(exp_x)

x = torch.tensor([1, 2, 3])
print(softmax(x))
# Out:
# tensor([0.0900, 0.2447, 0.6652])

# %% [markdown]
# **Section 3：强化学习与具身智能简答题（30 分）**

# %% [markdown]
# **🤖 Q6. 什么是具身智能（Embodied AI）？（10 分）**
#
# ✅ 答：
# 具身智能是“能感知、思考并行动”的人工智能，强调通过物理身体与环境交互获得认知能力。
# 在机器人中，它意味着“感知—决策—执行”的闭环，而不是仅仅视觉识别。

# %% [markdown]
# **🤖 Q7. 解释 Sim2Real（Simulation-to-Real）技术（10 分）**
#
# ✅ 答：
# Sim2Real 是将仿真中训练的模型迁移到真实机器人上。
# 常用技术包括：
#
# 域随机化（Domain Randomization）
#
# 图像增强与噪声注入
#
# 传感器建模
# 这些方法能减少仿真与现实差距，提高模型鲁棒性。

# %% [markdown]
# **🤖 Q8. 设计强化学习抓取任务的奖励函数（10 分）**
# 逻辑：惩罚距离、奖励抓取成功和平滑控制，保证稳定学习。

# %% [markdown]
# ```
# reward = -distance(object, target)
# if grasp_success:
#     reward += 10
# if action_is_smooth:
#     reward += 0.1
# ```
